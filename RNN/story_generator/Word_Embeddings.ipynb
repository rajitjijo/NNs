# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
word_to_index = {"I":0, "love":1, "eating":2, "and":3, "sleeping":5}
embeddings = nn.Embedding(5, 3)
word_index = torch.tensor(word_to_index["love"])

# %%
word_index
# Out:
# tensor(1)

# %%
love = embeddings(word_index)

# %%
love
# Out:
# tensor([ 0.6741, -0.1109,  0.1643], grad_fn=<EmbeddingBackward0>)

# %%
love.shape
# Out:
# torch.Size([3])

# %%
all_ind = torch.tensor([i for i in range(5)])

# %%
embeds = embeddings(all_ind)

# %%
embeds.shape
# Out:
# torch.Size([5, 3])

# %%
embeds
# Out:
# tensor([[ 1.2908,  0.8836, -0.2472],
#         [ 0.6741, -0.1109,  0.1643],
#         [ 0.6331, -1.0765, -0.1897],
#         [ 0.0784, -0.5171,  0.8457],
#         [ 0.7793, -0.9661,  0.2389]], grad_fn=<EmbeddingBackward0>)
